# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).
from pathlib import Path

food_data_candidates = (
    Path("data/food_coded.csv"),
    Path("../data/food_coded.csv"),
    Path("Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/food_coded.csv"),
)
food_data_set_path = next(path for path in food_data_candidates if path.exists())

df_food = pd.read_csv(food_data_set_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       1 # Load the Food choices data set into a variable (e.g., df_food).
#       2
#       3 food_data_set_path = 'data/food_coded.csv'
#       4
# ----> 5 df_food = pd.read_csv(food_data_set_path)
#
# ...

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    str
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    str
#  8   comfort_food_reasons          123 non-null    str
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
#  12  cuisine                       108 non-null    float64
# ...

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.columns
df_food.dtypes
# Out:
# GPA                     str
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports             str
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight                  str
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_food_filtered = df_food[['calories_day', 'weight', 'Gender']]
df_food_filtered.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   calories_day  106 non-null    float64
#  1   weight        123 non-null    str
#  2   Gender        125 non-null    int64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 8.4 KB

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
NaN_counts = df_food_filtered.isna().sum()
print(NaN_counts)
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_food_filtered = df_food_filtered.dropna()
df_food_filtered.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# Index: 104 entries, 1 to 123
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   calories_day  104 non-null    float64
#  1   weight        104 non-null    str
#  2   Gender        104 non-null    int64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 7.8 KB

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
df_food_filtered["weight"] = pd.to_numeric(
    df_food_filtered["weight"],
    errors="coerce"
)

df_food_filtered = df_food_filtered.dropna()

df_food_filtered.info(memory_usage="deep")
# Out:
# <class 'pandas.DataFrame'>
# Index: 101 entries, 1 to 123
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   calories_day  101 non-null    float64
#  1   weight        101 non-null    float64
#  2   Gender        101 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 3.2 KB

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
food_cleaned_path = food_data_set_path.with_name("food_cleaned.csv")
df_food_filtered.to_csv(food_cleaned_path, index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
from pathlib import Path

salary_file_name = "Ask A Manager salary survey 2021.tsv"
salary_data_candidates = (
    Path("data") / salary_file_name,
    Path("../data") / salary_file_name,
    Path("Week-02-Pandas-and-How-to-Make-a-Sick-Project/data") / salary_file_name,
)
salary_data_set_path = next(
    path for path in salary_data_candidates if path.exists()
)

df_salary = pd.read_csv(salary_data_set_path, sep="\t")

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %%
clean_salary_path = salary_data_set_path.with_name(
    "Ask_A_Manager_salary_survey_2021.csv"
)

df_salary.to_csv(clean_salary_path, index=False)
df_salary = pd.read_csv(clean_salary_path)

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_salary.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  str
# ...

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_salary.columns
df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed, gender, race
df_salary = df_salary.rename(
    columns={
        "Timestamp": "timestamp",
        "timestamp": "timestamp",
        "How old are you?": "age",
        "age": "age",
        "What industry do you work in?": "industry",
        "industry": "industry",
        "Job title": "title",
        "title": "title",
        "If your job title needs additional context, please clarify here:": "title_context",
        "title_context": "title_context",
        "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": "salary",
        "salary": "salary",
        "How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.": "additional_compensation",
        "additional_compensation": "additional_compensation",
        "Please indicate the currency": "currency",
        "currency": "currency",
        "If \"Other,\" please indicate the currency here: ": "other_currency",
        "other_currency": "other_currency",
        "If your income needs additional context, please provide it here:": "salary_context",
        "salary_context": "salary_context",
        "What country do you work in?": "country",
        "country": "country",
        "If you're in the U.S., what state do you work in?": "state",
        "state": "state",
        "What city do you work in?": "city",
        "city": "city",
        "How many years of professional work experience do you have overall?": "total_yoe",
        "total_yoe": "total_yoe",
        "How many years of professional work experience do you have in your field?": "field_yoe",
        "field_yoe": "field_yoe",
        "What is your highest level of education completed?": "highest_education_completed",
        "highest_education_completed": "highest_education_completed",
        "What is your gender?": "gender",
        "gender": "gender",
        "What is your race? (Choose all that apply.)": "race",
        "race": "race"
    }
)

df_salary.columns
# Out:
# Index(['timestamp', 'age', 'industry', 'title', 'title_context', 'salary',
#        'additional_compensation', 'currency', 'other_currency',
#        'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe',
#        'highest_education_completed', 'gender', 'race'],
#       dtype='str')

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
industries = df_salary['industry'].value_counts()
industries
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_salary_tech = df_salary[df_salary['industry'] == 'Computing or Tech']

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
salary_usd = df_salary_tech[df_salary_tech['currency'] == 'USD']
salary_usd
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                         title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
salary_usd['country'].value_counts().sort_values(ascending=False)
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Ghana                          1
# Nigeria                        1
# ss                             1
# Nigeria                        1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
salary_usd['country'] = salary_usd['country'].replace({
    'United States': 'US',
    'USA': 'US',
    'U.S.': 'US',
    'United States of America': 'US'
})

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
salary_usd["country"].value_counts()
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
#                   ...
# Ghana                1
# Nigeria              1
# ss                   1
# Nigeria              1
# Burma                1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
import re

def normalize_country(country):
    """Normalize country names by matching patterns case-insensitively."""
    if pd.isna(country):
        return country
    
   
    country_str = str(country).strip()
    country_lower = country_str.lower()
    
    
    if re.match(r'^u\.?s\.?a\.?$', country_lower) or \
       'united' in country_lower and 'state' in country_lower or \
       country_lower == 'us':
        return 'US'
    
   
    return country_str

salary_usd['country'] = salary_usd['country'].apply(normalize_country)

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
salary_usd['country'].value_counts()
# Out:
# country
# US                      3712
# Canada                     5
# Israel                     5
# U.S.                       2
# Unite States               2
# Australia                  2
# India                      2
# U.S                        2
# Spain                      2
# Brazil                     2
# United Kingdom             2
# New Zealand                2
# Poland                     2
# France                     2
# Nigeria                    2
# Uniyed states              1
# America                    1
# Puerto Rico                1
# U.s.                       1
# Cuba                       1
# Danmark                    1
# Italy                      1
# International              1
# Remote (philippines)       1
# Singapore                  1
# Uruguay                    1
# Mexico                     1
# ISA                        1
# singapore                  1
# Pakistan                   1
# Netherlands                1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
salary_usd['salary'] = pd.to_numeric(
    salary_usd['salary'].astype(str).str.replace(',', ''),
    errors='coerce'
)

salary_by_state = salary_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).reset_index()

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
salary_by_state['min'] = pd.to_numeric(salary_by_state['min'], errors='coerce')
salary_by_state['mean'] = pd.to_numeric(salary_by_state['mean'], errors='coerce')
salary_by_state['max'] = pd.to_numeric(salary_by_state['max'], errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
salary_by_state.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   66 non-null     str
#  1   min     66 non-null     int64
#  2   mean    66 non-null     float64
#  3   max     66 non-null     int64
# dtypes: float64(1), int64(2), str(1)
# memory usage: 5.6 KB

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

salary_usd['timestamp'] = pd.to_datetime(salary_usd['timestamp'])
salary_usd['year'] = salary_usd['timestamp'].dt.year

filtered_data = salary_usd[salary_usd['year'].isin([2021, 2022, 2023])]
salary_by_state_filtered = filtered_data.groupby('state')['salary'].agg(['min', 'mean', 'max']).reset_index()
salary_by_state_filtered
# Out:
#                             state     min           mean     max
# 0                         Alabama   29120   97738.181818  350000
# 1   Alabama, District of Columbia  156000  156000.000000  156000
# 2                Alabama, Montana   72000   72000.000000   72000
# 3                          Alaska   67000  112500.000000  158000
# 4                         Arizona   35000  104491.891892  210000
# ..                            ...     ...            ...     ...
# 61                        Vermont   65000  111781.250000  200000
# 62                       Virginia   43642  127706.355932  450000
# 63                     Washington      72  151571.970501  950000
# 64                  West Virginia  116500  120500.000000  125000
# 65                      Wisconsin       1  114268.000000  920000
#
# [66 rows x 4 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
df_salary_filtered = df_salary.copy()

df_salary_filtered["country"] = (
    df_salary_filtered["country"]
    .astype("string")
    .str.strip()
    .replace({
        "United States": "US",
        "USA": "US",
        "U.S.": "US",
        "United States of America": "US",
    })
)

df_salary_filtered = df_salary_filtered[
    (df_salary_filtered["currency"] == "USD")
    & (df_salary_filtered["country"] == "US")
].copy()

df_salary_filtered["salary"] = pd.to_numeric(
    df_salary_filtered["salary"].astype("string").str.replace(",", "", regex=False),
    errors="coerce",
)

df_salary_filtered = df_salary_filtered.dropna(subset=["state", "salary"])

salary_by_state_all = (
    df_salary_filtered.groupby("state")["salary"]
    .agg(["min", "mean", "max"])
    .sort_values("mean", ascending=False)
)

salary_by_state_all
# Out:
#                                                        min      mean     max
# state
# Indiana, Ohio                                       245000  245000.0  245000
# Colorado, Nevada                                    190000  190000.0  190000
# California, Texas                                   185000  185000.0  185000
# California, Montana                                 185000  185000.0  185000
# Georgia, Massachusetts                              175000  175000.0  175000
# ...                                                    ...       ...     ...
# District of Columbia, Washington                     35000   35000.0   35000
# Delaware, Pennsylvania                               35000   35000.0   35000
# Alabama, California                                  29120   29120.0   29120
# District of Columbia, Maryland, Pennsylvania, V...   27040   27040.0   27040
# Maryland, New York                                   14000   14000.0   14000
#
# [120 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
salary_by_state_all.style.format(
    {
        "min": "${:,.2f}",
        "mean": "${:,.2f}",
        "max": "${:,.2f}",
    }
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_83dc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83dc9_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_83dc9_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_83dc9_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83dc9_level0_row0" class="row_heading level0 row0" >Indiana, Ohio</th>
#       <td id="T_83dc9_row0_col0" class="data row0 col0" >$245,000.00</td>
#       <td id="T_83dc9_row0_col1" class="data row0 col1" >$245,000.00</td>
#       <td id="T_83dc9_row0_col2" class="data row0 col2" >$245,000.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
single_states = salary_by_state_all[~salary_by_state_all.index.str.contains(",")]
single_states
# Out:
#                         min           mean      max
# state
# California                0  114922.253988   875000
# Washington               72  107698.932796  1260000
# District of Columbia     40  106163.270588  1334782
# New York                 80  105260.574891  3000000
# Massachusetts          4100   98770.581818  1650000
# Virginia                 57   95093.689373  1300000
# Connecticut               0   94514.079439  1900000
# Illinois                  0   89741.617988  1100000
# Maryland                  0   89582.948473   353200
# Colorado                 65    89438.08557   630000
# Oregon                    0   89224.296741   320000
# Texas                     0   88532.346543  1200000
# New Jersey            14850    88006.08871   400000
# Utah                  18720   87590.984456   576000
# Delaware              35000   86352.568182   220000
# Georgia                   0   85161.784314   415000
# New Mexico              130   84259.137931   300000
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
quantile_levels = [0, 0.05, 0.25, 0.5, 0.75, 0.95, 1]
single_state_salary = df_salary_filtered[
    ~df_salary_filtered["state"].str.contains(",", na=False)
]

salary_by_state_quantiles = (
    single_state_salary.groupby("state")["salary"]
    .quantile(quantile_levels)
    .unstack()
    .rename(columns=lambda level: f"p{level:g}")
    .assign(count=single_state_salary.groupby("state")["salary"].count())
    .sort_values("p0.5", ascending=False)
)

salary_by_state_quantiles
# Out:
#                            p0     p0.05     p0.25      p0.5     p0.75  \
# state
# California                0.0   42128.0   72000.0  101050.0  147000.0
# Washington               72.0   40000.0   66375.0   92000.0  135000.0
# District of Columbia     40.0   48000.0   66150.0   90000.0  124525.5
# New York                 80.0   41020.0   64000.0   89000.0  126500.0
# Massachusetts          4100.0   42500.0   64000.0   85350.0  120000.0
# Maryland                  0.0   40000.0   60000.0   82000.0  110000.0
# Connecticut               0.0   33702.5   61250.0   81900.0  100000.0
# Delaware              35000.0   41662.4  59623.25   81322.5  105250.0
# Virginia                 57.0   37804.0   59000.0   81000.0  114850.0
# Oregon                    0.0   36460.0   60000.0   78000.0  109153.0
# Illinois                  0.0   37404.0   55270.0   76000.0  107250.0
# Colorado                 65.0   39245.0   58000.0   75550.0  107250.0
# ...
